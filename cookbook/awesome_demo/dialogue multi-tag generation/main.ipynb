# %% [markdown]
# # 客服对话多标签生成
#
# 在客服对话场景中，可以通过大模型分析用户与客服之间的对话信息，准确识别用户的意图和对应原因，生成对应标签为后续回复和营销策略服务。比如，用户因地址填写错误与客服沟通，说希望能够取消订单，则取消订单是意图，地址填写错误是原因。最初我们选择小模型进行多标签生成，在初期使用中展现出一定的效果，能够在较短时间内进行部署并提供基础的标签生成功能。然而，随着业务需求的日益复杂，现有的小模型在多标签生成上存在一些明显的问题和挑战：
#
#
# * 标签准确率不高：小模型的标签准确率通常保持在接近80%左右，无法满足业务进一步提高准确率的期望。业务需求日益复杂，用户提出的问题多样化，小模型的识别能力有限，导致部分标签无法准确标识。
# * 标注数据需求量大：训练一个有效的小模型，每个标签至少需要300个标注数据，人工成本高昂。尤其是在业务需求不断变化的情况下，标注工作量进一步增加。
# * 对标签体系的依赖性强：小模型对标签体系还会有较强的依赖，一旦业务标签体系发生较大变化，例如三层标签扩展到四层标签或大规模调整标签结构，标注和训练工作需要大规模重复建设。
#
#
# 针对上述问题，我们提出了使用ERNIE Tiny大模型进行微调的解决方案。ERNIE Tiny大模型在语言理解能力上更强，能够在较少标注数据的情况下，达到或超过现有小模型的准确率要求。通过微调训练，ERNIE Tiny大模型能够更好地适应业务需求的变化，提高多标签生成的准确性和效率，从而更好地支持客服对话场景的应用。

# %% [markdown]
# # 0. 环境准备

# %%
from qianfan import ChatCompletion
from qianfan.dataset import Dataset
from qianfan.common import Prompt
from qianfan.trainer import LLMFinetune
from qianfan.trainer.consts import PeftType
from qianfan.trainer.configs import TrainConfig
import os
from qianfan.dataset import Dataset
from qianfan.dataset.data_source.base import FormatType

# %%
os.environ["QIANFAN_ACCESS_KEY"] = "your_access_key"
os.environ["QIANFAN_SECRET_KEY"] = "your_secret_key"

# %% [markdown]
# # 1. 基座模型效果示例

# %% [markdown]
# 首先，我们选择了ERNIE-Tiny-8K模型作为本次实验的基座模型。
#
# 此处设置两个案例，带您直观了解微调前模型的输出问题

# %%
chat = ChatCompletion(model="ERNIE-Tiny-8K")

# %% [markdown]
# ## 例一

# %%
target ={ 
    "conversation": (
        "王琳K：欢迎光临DianCan披萨，为了给您提供更加优质的服务，请问您有什么具体的问题或需要帮助吗？"
        "客户李先生：我刚刚下了一个订单，但是地址写错了，能帮我取消吗？"
        "王琳K：非常抱歉给您带来困扰，我可以帮您取消订单。为了确认您的身份，需要您提供订单号或者下单时使用的电话号码，可以吗？"
        "客户李先生：我的订单号是DC123456789，电话号码是138****1234。"
        "王琳K：非常感谢您提供的信息，我已经找到了您的订单。现在我将为您取消该订单，请稍等片刻。"
        "客户李先生：好的，谢谢。"
        "王琳K：您的订单已经成功取消。如有其他问题，请随时联系我们。感谢您的理解和支持。"
        "客户李先生：非常感谢你们的帮助，我会重新下单的。"
        "王琳K：非常高兴能够帮助您解决问题。祝您用餐愉快！如有其他问题，请随时联系我们。"
)
}
prompt = Prompt("""你是一个对话意图识别并打标签的机器人，根据下面的已知信息，打上标签。
                请使用以下格式输出：{"意图": xxx
                                "原因": xxx}
请根据以下会话的内容，精准判断最有可能的客户意图以及对应的原因标签，意图和原因标签必须严格控制在给定的范围之内。：

{conversation}
""")

resp = chat.do(messages=[{"role": "user", "content": prompt.render(**target)[0]}])

print(resp["result"])
# Out:
# 根据对话内容，最有可能的客户意图和对应的原因标签是：
# “客户意图”：订单取消
# “原因标签”：解决问题
#
# 解释：客户李先生表示地址写错了需要取消订单，王琳K表示可以帮他取消订单并提供了相应的帮助。因此，可以判断客户的意图是订单取消。

# %% [markdown]
# ## 例二

# %%
target ={ 
    "conversation": (
        "DianCan 自助点餐机器人：您好，欢迎光临DianCan披萨，有什么可以为您服务的吗？"
        "顾客：你好，我刚刚下了一个订单，但是我发现我填写的地址是错的。"
        "DianCan 自助点餐机器人：非常抱歉给您带来困扰。请问您是否希望取消订单并重新下单呢？"
        "顾客：是的，我想取消订单。"
        "DianCan 自助点餐机器人：好的，请告诉我您的订单号，我会尽快帮您处理。"
        "顾客：我的订单号是XXXX。"
        "DianCan 自助点餐机器人：好的，已经为您查询到了订单。为了确认您的身份，请问您能提供下单时使用的手机号码后四位吗？"
        "顾客：手机号码后四位是XXXX。"
        "DianCan 自助点餐机器人：非常感谢，已经确认您的身份。我们现在就为您取消订单，并会尽快处理退款。退款将在3-7个工作日内原路返回至您的支付账户。请您注意查收。"
        "顾客：好的，非常感谢你们的帮助。"
        "DianCan 自助点餐机器人：不客气，如果您还有其他问题或需要进一步的帮助，请随时与我们联系。祝您用餐愉快！"
)
}

resp = chat.do(messages=[{"role": "user", "content": prompt.render(**target)[0]}])

print(resp["result"])
# Out:
# ```json
# {
# "意图": "客户服务",
# "原因": "顾客表达想要取消订单，处理地址错误的情况，机器人回应询问订单号和手机号码后四位以确认身份，并提供了处理订单取消及退款的具体措施"
# }
# ```

# %% [markdown]
# 从上述两组例子中，我们可以总结出以下问题：
#
#
# * 问题一：微调前模型的输出可能并不能完全遵循指定格式进行输出。
# * 问题二：基座模型的输出无法精准识别客户意图和原因。

# %% [markdown]
# # 2. 模型精调数据准备

# %% [markdown]
# ## 2.1 构造“意图-原因”标签集

# %% [markdown]
# 首先，将收集到的数据集进行标签注解。
#
# 根据客服对话的内容，提炼客户意见与相应的发起客服对话原因，进行数据编号的标注，如下为例：

# %% [markdown]
# | 意见                       | 原因                          | 数据编号 |
# |----------------------------|-------------------------------|----------|
# | 如何提交评价               | 未收到评价请求               | 1        |
# | 你们有某种餐品吗          | 餐品缺货、短期或长缺         | 1        |
# | 某餐需要做成不辣          | 顾客特殊需求                 | 1        |
# | 在餐厅怎么买东西怎么回    | 找回遗失物品                 | 1        |
# | 订单什么时候能做好        | 餐品制作时间                 | 1        |
# | 如何访问我的订单历史记录 | 订单历史订单详情            | 1        |
# | 取消订单                  | 取消订单_具体原因           | 1        |
# | 为什么我的优惠券没见了    | 优惠券未到期                 | 1        |
# | 取消订单                  | 地址填写错误                 | 1        |
# | 我想要把单品或套餐添加/删除 | j1或添加单品_质量定制       | 2        |
# | 餐品不对                  | 源错误                       | 1        |
# | 餐品配送太少              | 食物波动                     | 1        |
# | 我在餐厅可以参与活动吗    | 活动相关咨询                 | 1        |
# | 有关于推荐的商品          | 需要推荐咨询                 | 1        |
# | 我在餐厅开发票            | 开发票                       | 2        |

# %% [markdown]
# ## 2.2 生成对话数据

# %% [markdown]
# 根据上述案例，从”意图-原因“生成客服对话的Prompt如下所示：

# %%
conversation_prompt ="""你是一个利用【意图-原因】生成对话的机器人，请你仔细观察下面的输入输出，发挥你的想象，根据【输入】提供的已知信息和要求，生成客服对话。具体要求如下：
1.【输入】和【输出】的格式与示例相同。
2.【输出】为生成的对话。
3.你生成的是DianCan披萨公司的客服对话，请你刻意回避百胜公司、肯德基餐饮相关的产品和名词。
遵循以上准则，请你根据【输入】创造一个新的客服对话，示例如下：

【输入】
###意图-原因
"{"意图": "某产品你们有吗"
"原因": "产品是否有_餐厅断货_临时or永久"}"
【输出】
### 对话内容
"客服:正在为您转接人工服务中，目前人工繁忙，如需继续等待请输入：继续
客服:欢迎进入人工客服通道，56959很高兴为您服务对话过程中以及完成后，您会收到评价提醒，希望您能对我个人本次服务做个评价，您的反馈和建议也是我努力的方向哦，感谢~
顾客:继续
顾客:你好，鸡腿饭现在是下架了嘛
客服:DianCan客服中心，很高兴为您服务，我先查看一下您反馈的问题哦~
顾客:附近每家店子都没有[嚎哭]
客服:没有看到说明售罄，暂时断货，没有这个餐点，建议客官过段时间在购买查看的，不好意思。
客服:以您在我们官网看到的为准，有就是有，没有就是没有的呢。
顾客:那可以查一下附近哪家店有吗
顾客:武汉洪山区哪家店有
顾客:我看了好多家都没有[嚎哭]
客服:小二这边是客服中心的，不是某家餐厅，不是很清楚每个门店的具体情况，非常抱歉。
客服:或者您可以通过DianCan微信公众号-自助服务-点击入群，可加入附近DianCan餐厅的社群哦~了解具体信息。
客服:亲亲，您还在线吗？我还在快马加鞭处理中，如果您还有问题，也及时回应哦~
客服:"
---------------------------------
【输入】    
###意图-原因
"{"意图": "你们有某种餐品吗"
"原因": "餐品断货_短期或长期"}"
【输出】："""

# %%
resp = chat.do(messages=[{"role": "user", "content": conversation_prompt}])
print(resp["result"])
# Out:
# 客服：您好，目前正在为您查询，关于您提到的餐品，我们暂时没有收到关于断货或下架的信息。建议您可以通过我们的官网或者微信公众号了解最新产品信息。如果您需要其他帮助或有其他问题，请随时告知，我们会尽快为您处理。
#
# 如果您对餐品的供应情况有疑问或需要了解更多信息，建议您通过我们的官方渠道查询最新消息。如果您还有其他问题或需求，请随时告知，我们会竭诚为您服务。

# %% [markdown]
# # 3. SFT调优示例

# %% [markdown]
# ## 3.1 数据集导入

# %% [markdown]
# 在完成上述的数据集准备工作后，我们可以开始进行模型微调训练。

# %% [markdown]
# 首先从平台中获取微调用的训练集

# %%
ds = Dataset.load(qianfan_dataset_id = "ds-scm8g98a7pv3zzf3", format = FormatType.Jsonl)
print(ds[0])
# Out:
# [INFO][2024-08-12 16:47:47.213] dataset.py:430 [t:8570851136]: no data source was provided, construct
# [INFO][2024-08-12 16:47:47.214] dataset.py:282 [t:8570851136]: construct a qianfan data source from existed id: ds-scm8g98a7pv3zzf3, with args: {'format': <FormatType.Jsonl: 'jsonl'>}
# [INFO][2024-08-12 16:47:47.989] dataset_utils.py:317 [t:8570851136]: list qianfan dataset data by 0
# [INFO][2024-08-12 16:47:48.404] dataset_utils.py:339 [t:8570851136]: received dataset list from qianfan dataset
# [INFO][2024-08-12 16:47:48.405] dataset_utils.py:347 [t:8570851136]: retrieve single entity from https://easydata.bj.bcebos.com/_system_/dataset/ds-scm8g98a7pv3zzf3/texts/data/raw_aca7da8ef71c956315d9a7dc3874a4d5a65280bb382263c39aa16482de1b666e_91dc9885731b405bb32a5d5734c4dd5f?authorization=bce-auth-v1%2F50c8bb753dcb4e1d8646bb1ffefd3503%2F2024-08-12T08%3A47%3A48Z%2F7200%2Fhost%2F4042ce5b329d3026629877a2108adae8293bc615d5b4cc9c76948f9a2a917147 in try 0
# [INFO][2024-08-12 16:47:48.631] dataset_utils.py:361 [t:8570851136]: retrieve single entity from https://easydata.bj.bcebos.com/_system_/dataset/ds-scm8g98a7pv3zzf3/texts/data/raw_aca7da8ef71c956315d9a7dc3874a4d5a65280bb382263c39aa16482de1b666e_91dc9885731b405bb32a5d5734c4dd5f?authorization=bce-auth-v1%2F50c8bb753dcb4e1d8646bb1ffefd3503%2F2024-08-12T08%3A47%3A48Z%2F7200%2Fhost%2F4042ce5b329d3026629877a2108adae8293bc615d5b4cc9c76948f9a2a917147 succeeded, with content: [{"prompt": "假设你有一套客户意图分类以及该分类下属的原因标签。请根据给定的客服对话内容，判断最有可能的客户意图以及对应的原因标签，意图和原因标签需要严格控制给定的范围之内；一个意图可能对应多个原因，但一个原因只会对应一个意图；如果均不匹配则回答无明确客户意图；回答请使用json的格式，示例：'{\"意图\": \"xxx\",\"原因”: \"xxx\"}'\n### 下面是客户意图的分类\n1.客户意图：如何提交评价;原因标签：未收到评价邀请\n2.客户意图：你们有某种餐品吗;原因标签：餐品缺货_短期或长期\n3.客户意图：某餐品需要做成不辣;原因标签：顾客特需服务\n4.客户意图：在餐厅丢失了物品怎么寻回;原因标签：找回遗失物品\n5.客户意图：订单什么时候能做好;原因标签：餐品制作时间\n6.客户意图：如何访问我的订单历史记录;原因标签：历史订单查询\n7.客户意图：取消订单;原因标签：取消订单_无具体理由\n8.客户意图：为什么我的优惠券不见了;原因标签：优惠券未到账\n9.客户意图：取消订单;原因标签：地址填写错误\n10.客户意图：我想要加番茄酱或者不加番茄酱;原因标签：加or不加番茄酱_顾客定制\n11.客户意图：餐品不对;原因标签：漏餐错餐\n12.客户意图：餐厅电话是多少;原因标签：食物变质\n13.客户意图：我在哪里可以参加活动;原因标签：活动地点咨询\n14.客户意图：有没有推荐的产品;原因标签：需要推荐餐品\n15.客户意图：客户要开发票;原因标签：开发票\n\n###对话内容\n李星辰DY    2023年07月19日 10:23:48\n您好，欢迎光临DianCan披萨，有什么可以为您服务的吗？\n用户673210    2023年07月19日 10:24:12\n我想开一下发票\n李星辰DY    2023年07月19日 10:24:35\n当然可以，请您提供一下订单号和开票信息，我们会尽快为您处理。\n用户673210    2023年07月19日 10:25:01\n订单号是DC230715001，开票信息是公司名称：XX科技有限公司，税号：9132XXXXXXXXX\n李星辰DY    2023年07月19日 10:25:38\n好的，已经收到您的订单号和开票信息，我们会尽快为您开具发票并发送到您的邮箱。请问您的邮箱地址是什么？\n用户673210    2023年07月19日 10:26:05\n我的邮箱是[example@example.com](mailto:example@example.com)\n李星辰DY    2023年07月19日 10:26:32\n非常感谢，我们已经记录下了您的邮箱地址。发票将在24小时内发送到您的邮箱，请注意查收。\n用户673210    2023年07月19日 10:27:00\n好的，谢谢！\n李星辰DY    2023年07月19日 10:27:25\n不客气，如果您有任何其他问题或需要进一步的帮助，请随时联系我们。祝您用餐愉快！\n\n###输出", "response": [["{'意图': '客户要开发票', '原因': '开发票'}"]]}]
# [{'entity_id': 'aca7da8ef71c956315d9a7dc3874a4d5a65280bb382263c39aa16482de1b666e_91dc9885731b405bb32a5d5734c4dd5f', 'entity_content': '[{"prompt": "假设你有一套客户意图分类以及该分类下属的原因标签。请根据给定的客服对话内容，判断最有可能的客户意图以及对应的原因标签，意图和原因标签需要严格控制给定的范围之内；一个意图可能对应多个原因，但一个原因只会对应一个意图；如果均不匹配则回答无明确客户意图；回答请使用json的格式，示例：\'{\\"意图\\": \\"xxx\\",\\"原因”: \\"xxx\\"}\'\\n### 下面是客户意图的分类\\n1.客户意图：如何提交评价;原因标签：未收到评价邀请\\n2.客户意图：你们有某种餐品吗;原因标签：餐品缺货_短期或长期\\n3.客户意图：某餐品需要做成不辣;原因标签：顾客特需服务\\n4.客户意图：在餐厅丢失了物品怎么寻回;原因标签：找回遗失物品\\n5.客户意图：订单什么时候能做好;原因标签：餐品制作时间\\n6.客户意图：如何访问我的订单历史记录;原因标签：历史订单查询\\n7.客户意图：取消订单;原因标签：取消订单_无具体理由\\n8.客户意图：为什么我的优惠券不见了;原因标签：优惠券未到账\\n9.客户意图：取消订单;原因标签：地址填写错误\\n10.客户意图：我想要加番茄酱或者不加番茄酱;原因标签：加or不加番茄酱_顾客定制\\n11.客户意图：餐品不对;原因标签：漏餐错餐\\n12.客户意图：餐厅电话是多少;原因标签：食物变质\\n13.客户意图：我在哪里可以参加活动;原因标签：活动地点咨询\\n14.客户意图：有没有推荐的产品;原因标签：需要推荐餐品\\n15.客户意图：客户要开发票;原因标签：开发票\\n\\n###对话内容\\n李星辰DY    2023年07月19日 10:23:48\\n您好，欢迎光临DianCan披萨，有什么可以为您服务的吗？\\n用户673210    2023年07月19日 10:24:12\\n我想开一下发票\\n李星辰DY    2023年07月19日 10:24:35\\n当然可以，请您提供一下订单号和开票信息，我们会尽快为您处理。\\n用户673210    2023年07月19日 10:25:01\\n订单号是DC230715001，开票信息是公司名称：XX科技有限公司，税号：9132XXXXXXXXX\\n李星辰DY    2023年07月19日 10:25:38\\n好的，已经收到您的订单号和开票信息，我们会尽快为您开具发票并发送到您的邮箱。请问您的邮箱地址是什么？\\n用户673210    2023年07月19日 10:26:05\\n我的邮箱是[example@example.com](mailto:example@example.com)\\n李星辰DY    2023年07月19日 10:26:32\\n非常感谢，我们已经记录下了您的邮箱地址。发票将在24小时内发送到您的邮箱，请注意查收。\\n用户673210    2023年07月19日 10:27:00\\n好的，谢谢！\\n李星辰DY    2023年07月19日 10:27:25\\n不客气，如果您有任何其他问题或需要进一步的帮助，请随时联系我们。祝您用餐愉快！\\n\\n###输出", "response": [["{\'意图\': \'客户要开发票\', \'原因\': \'开发票\'}"]]}]'}]

# %% [markdown]
# ## 3.2 微调训练
#
# 拿到一个训练场景或者任务后，往往比较难判断参数应该如何调整。一般使用默认的参数值进行训练即可，平台中的默认参数是多次实验的经验结晶。 接下来介绍参数配置中有两个较为关键的参数：
#
# * 迭代轮次（Epoch）: 控制训练过程中的迭代轮数。轮数增加代表会使用训练集对模型训练一次。
#
# * 学习率（Learning Rate）: 是在梯度下降的过程中更新权重时的超参数，过高会导致模型难以收敛，过低则会导致模型收敛速度过慢，平台已给出默认推荐值，也可根据经验调整。
#
# * 序列长度：如果对话数据的长度较短，建议选择短的序列长度，可以提升训练的速度。
#
# 本次也针对Epoch和Learning Rate进行简要的调参实验，详细实验结果可以看效果评估数据。
#
# 如果您是模型训练的专家，千帆也提供了训练更多的高级参数供您选择。这里也建议您初期调参时步长可以设定稍大些，因为较小的超参变动对模型效果的影响小，会被随机波动掩盖。

# %% [markdown]
# 创建trainer任务

# %%
trainer = LLMFinetune(
    name = "dialogue-multi-tag",
    train_type="ERNIE-Tiny-8K",
    train_config=TrainConfig(
        epoch=1,
        learning_rate=1e-5,
        peft_type=PeftType.ALL,
    ),
    dataset=ds
)

# %% [markdown]
# 启动训练任务

# %%
trainer.start()
print(trainer.result)
# Out:
# [INFO][2024-08-12 16:51:44.361] base.py:226 [t:8570851136]: trainer subprocess started, pid: 11416
# [None]
# [INFO][2024-08-12 16:51:44.368] base.py:202 [t:8570851136]: check running log in .qianfan_exec_cache/ZdTRr7iw/2024-08-12.log

# %%
trainer.output
# Out:
# [INFO][2024-08-12 17:23:18.156] dataset.py:430 [t:8570851136]: no data source was provided, construct
# [INFO][2024-08-12 17:23:18.157] dataset.py:282 [t:8570851136]: construct a qianfan data source from existed id: ds-scm8g98a7pv3zzf3, with args: {}
# {'datasets': {'versions': [{'versionId': 'ds-scm8g98a7pv3zzf3'}],
#   'sourceType': 'Platform',
#   'splitRatio': 20},
#  'task_id': 'task-85tcmxg0try3',
#  'job_id': 'job-xhk1gtuvvdbh',
#  'metrics': {'BLEU-4': '99.58%',
#   'ROUGE-1': '99.62%',
#   'ROUGE-2': '99.60%',
#   'ROUGE-L': '99.75%',
#   'EDIT-DISTANCE': '0.11',
#   'EMBEDDING-DISTANCE': '0.00'},
#  'checkpoints': [],
#  'model_set_id': 'am-mgf6icsebsa4',
#  'model_id': 'amv-8t6qf24m4xcb'}

# %% [markdown]
# ## 3.3 结果评估

# %% [markdown]
# 在这一部分中，我们可以对刚才训练好的模型进行评估，评估模型的微调效果。
#
# 针对客服对话意图识别场景的评估任务，我们需要制定如下规则与方法：
#
# * 评估规则：在客服对话多标签生成中，结果相对清晰明确。可定义评分规则，评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。
#
#
# * 评估方式：实施自动打分，将评分标准、场景要求、上下文、大模型的回答拼接成一个Prompt，使用EB4等大模型进行自动打分。

# %% [markdown]
# 首先，导入训练好的模型：

# %%
from qianfan.model import Model

# 从`version_id`构造模型：
m = Model(id='amv-8t6qf24m4xcb')
# Out:
# [TRACE][2024-08-14 16:10:55.096] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/modelVersionDetail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:10:55Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:10:55Z/300/x-bce-date;content-type;request-source;host/94f6326ddcd96fb90a8bfb86ca08d709607160be6334525bdbf77cfcbd6230e3'}, json_body={'modelVersionId': 'amv-8t6qf24m4xcb'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))

# %% [markdown]
# 导入相应训练集

# %%
eval_ds = Dataset.load(qianfan_dataset_id ="ds-n1dg1czx3ciqrakr",organize_data_as_group=False, input_columns=["prompt"], reference_column="response")
# Out:
# [INFO][2024-08-14 16:43:13.466] dataset.py:430 [t:8570851136]: no data source was provided, construct
# [INFO][2024-08-14 16:43:13.466] dataset.py:282 [t:8570851136]: construct a qianfan data source from existed id: ds-n1dg1czx3ciqrakr, with args: {'input_columns': ['prompt'], 'reference_column': 'response'}
# [TRACE][2024-08-14 16:43:13.467] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/dataset/info', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:43:13Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:43:13Z/300/x-bce-date;content-type;request-source;host/c295693a48c205dd2be180918b1ec4c2a58fc373a2b296a57913ccd714f1b479'}, json_body={'datasetId': 'ds-n1dg1czx3ciqrakr'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))

# %% [markdown]
# 创建本次评估任务
#
#
# 本次评估采用了在线裁判员评估打分方式，因此使用了QianfanRefereeEvaluator作为本次的评估器。
#
# 其中涉及到了以下参数：
#
# * prompt_steps:填写评估的打分方式与方法
# * prompt_metrics:分数最终呈现的形式。默认为“综合得分”
# * prompt_max_score:评估的最大分数。默认为3

# %%
from qianfan.evaluation.evaluator import QianfanRefereeEvaluator, QianfanRuleEvaluator
from qianfan.evaluation.consts import QianfanRefereeEvaluatorDefaultMetrics
from qianfan.utils.logging import enable_log, TRACE_LEVEL
enable_log(TRACE_LEVEL)
your_app_id = 105835560

qianfan_evaluators = [
    QianfanRefereeEvaluator(
        prompt_steps= """
请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。""",
        app_id=your_app_id,
        prompt_metrics=QianfanRefereeEvaluatorDefaultMetrics,
        prompt_max_score=3,
    )
    
]

# %% [markdown]
# 执行评估任务

# %%
from qianfan.evaluation import EvaluationManager

em = EvaluationManager(qianfan_evaluators=qianfan_evaluators)
result = em.eval([m], eval_ds)
# Out:
# [TRACE][2024-08-14 16:10:58.012] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/modelVersionDetail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:10:58Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:10:58Z/300/x-bce-date;content-type;request-source;host/5898cdbce6b2f7b93f0b2483014ab16be1ab4042b9b19277cb748302a6e539b6'}, json_body={'modelVersionId': 'amv-8t6qf24m4xcb'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [TRACE][2024-08-14 16:10:58.493] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/create', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:10:58Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:10:58Z/300/x-bce-date;content-type;request-source;host/092d4dce3933787a0389379cfdef305a77e7c55b3ef6e4872456ab2449f56457'}, json_body={'name': 'sdk_eval_MCTK5U2uNE6', 'versionEvalInfo': [{'modelId': 'am-mgf6icsebsa4', 'modelVersionId': 'amv-8t6qf24m4xcb'}], 'datasetId': 'ds-n1dg1czx3ciqrakr', 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'maxScore': 3}}, 'computeResourceConf': {'vmType': 1, 'vmNumber': 8}}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [INFO][2024-08-14 16:11:00.310] evaluation_manager.py:377 [t:8570851136]: please check webpage https://console.bce.baidu.com/qianfan/modelcenter/model/eval/detail/task/ame-v86j3sw988t0 to get further information
# [TRACE][2024-08-14 16:11:00.312] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:11:00Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:11:00Z/300/x-bce-date;content-type;request-source;host/aed795437c85af398aea689a193b6c6405a79030da7cbc7259d6ace3c4f1b429'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:11:00.604] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:11:00 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3771', 'X-Bce-Request-Id': '7c64f43d-b157-49ee-8f92-f1fff0fac873', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '2648445740', 'result': {'evaluationId': 15546, 'evaluationIdStr': 'ame-v86j3sw988t0', 'name': 'sdk_eval_MCTK5U2uNE6', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 42564, 'modelVersionIdStr': 'amv-8t6qf24m4xcb', 'modelId': 34491, 'modelIdStr': 'am-mgf6icsebsa4', 'modelName': 'm_xNDPALyMT4db', 'modelVersion': '1', 'modelSource': 'Train', 'state': 'Doing', 'modelVersionDesc': '', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-e6idgpqm5t3d', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.286813, 'total_latency': 0.2901199589978205, 'start_timestamp': 1723623060312}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:11:00Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:11:00Z/300/x-bce-date;content-type;request-source;host/aed795437c85af398aea689a193b6c6405a79030da7cbc7259d6ace3c4f1b429', 'Content-Length': '26'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:11:00.605] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:11:30.612] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:11:30Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:11:30Z/300/x-bce-date;content-type;request-source;host/ad5abba9ee70191f67dd5bd0cb48d6ce0fd5811db7e7d09c19aacfc95f92d4e4'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:11:30.923] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:11:30 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3771', 'X-Bce-Request-Id': '8acd5e2c-5819-4494-bd0e-73dfc90c733e', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '2931975866', 'result': {'evaluationId': 15546, 'evaluationIdStr': 'ame-v86j3sw988t0', 'name': 'sdk_eval_MCTK5U2uNE6', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 42564, 'modelVersionIdStr': 'amv-8t6qf24m4xcb', 'modelId': 34491, 'modelIdStr': 'am-mgf6icsebsa4', 'modelName': 'm_xNDPALyMT4db', 'modelVersion': '1', 'modelSource': 'Train', 'state': 'Doing', 'modelVersionDesc': '', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-e6idgpqm5t3d', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.304781, 'total_latency': 0.30778750000172295, 'start_timestamp': 1723623090613}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:11:30Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:11:30Z/300/x-bce-date;content-type;request-source;host/ad5abba9ee70191f67dd5bd0cb48d6ce0fd5811db7e7d09c19aacfc95f92d4e4', 'Content-Length': '26'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:11:30.924] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:12:00.930] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:12:00Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:12:00Z/300/x-bce-date;content-type;request-source;host/1ca11ac4659f6fe6c2835b2fb7118a2ce2a319dcd5fc1b7e221a2f1cfe2644d8'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:12:01.314] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:12:01 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3771', 'X-Bce-Request-Id': '59c97003-6d02-4091-aa6f-25ea1b2a1b61', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '3233749133', 'result': {'evaluationId': 15546, 'evaluationIdStr': 'ame-v86j3sw988t0', 'name': 'sdk_eval_MCTK5U2uNE6', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 42564, 'modelVersionIdStr': 'amv-8t6qf24m4xcb', 'modelId': 34491, 'modelIdStr': 'am-mgf6icsebsa4', 'modelName': 'm_xNDPALyMT4db', 'modelVersion': '1', 'modelSource': 'Train', 'state': 'Doing', 'modelVersionDesc': '', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-e6idgpqm5t3d', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.374183, 'total_latency': 0.37908545800019056, 'start_timestamp': 1723623120931}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:12:00Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:12:00Z/300/x-bce-date;content-type;request-source;host/1ca11ac4659f6fe6c2835b2fb7118a2ce2a319dcd5fc1b7e221a2f1cfe2644d8', 'Content-Length': '26'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:12:01.315] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:12:31.322] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:12:31Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:12:31Z/300/x-bce-date;content-type;request-source;host/a730a7a30f6d105c3469c291d8b7402e542412dfc9ee11ca1817f3afdc258a9d'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:12:31.693] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:12:31 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3771', 'X-Bce-Request-Id': 'bbc104e5-341e-4ec5-935a-0f4131bd37aa', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '3566506481', 'result': {'evaluationId': 15546, 'evaluationIdStr': 'ame-v86j3sw988t0', 'name': 'sdk_eval_MCTK5U2uNE6', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 42564, 'modelVersionIdStr': 'amv-8t6qf24m4xcb', 'modelId': 34491, 'modelIdStr': 'am-mgf6icsebsa4', 'modelName': 'm_xNDPALyMT4db', 'modelVersion': '1', 'modelSource': 'Train', 'state': 'Doing', 'modelVersionDesc': '', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-e6idgpqm5t3d', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.361426, 'total_latency': 0.36618224999983795, 'start_timestamp': 1723623151323}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:12:31Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:12:31Z/300/x-bce-date;content-type;request-source;host/a730a7a30f6d105c3469c291d8b7402e542412dfc9ee11ca1817f3afdc258a9d', 'Content-Length': '26'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:12:31.693] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:13:01.700] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:13:01Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:13:01Z/300/x-bce-date;content-type;request-source;host/6fdb858f29570a17974425e53488f5fd6eeeee05a6438e676a5bff43435918e7'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:13:02.007] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:13:02 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3771', 'X-Bce-Request-Id': '342c70a1-d50f-4758-a50c-99c08dee6fa7', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '3797120224', 'result': {'evaluationId': 15546, 'evaluationIdStr': 'ame-v86j3sw988t0', 'name': 'sdk_eval_MCTK5U2uNE6', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 42564, 'modelVersionIdStr': 'amv-8t6qf24m4xcb', 'modelId': 34491, 'modelIdStr': 'am-mgf6icsebsa4', 'modelName': 'm_xNDPALyMT4db', 'modelVersion': '1', 'modelSource': 'Train', 'state': 'Doing', 'modelVersionDesc': '', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-e6idgpqm5t3d', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.298676, 'total_latency': 0.3023175409907708, 'start_timestamp': 1723623181701}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:13:01Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:13:01Z/300/x-bce-date;content-type;request-source;host/6fdb858f29570a17974425e53488f5fd6eeeee05a6438e676a5bff43435918e7', 'Content-Length': '26'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:13:02.008] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:13:32.015] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:13:32Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:13:32Z/300/x-bce-date;content-type;request-source;host/fe68b2111fd186159f8c9f59d281f6d2d44fc5b9d16cf8764b9b41ca44ed7792'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:13:32.301] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:13:32 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3771', 'X-Bce-Request-Id': '85dc8838-81cb-49b1-a1ba-8defba30e1d5', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '4058448948', 'result': {'evaluationId': 15546, 'evaluationIdStr': 'ame-v86j3sw988t0', 'name': 'sdk_eval_MCTK5U2uNE6', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 42564, 'modelVersionIdStr': 'amv-8t6qf24m4xcb', 'modelId': 34491, 'modelIdStr': 'am-mgf6icsebsa4', 'modelName': 'm_xNDPALyMT4db', 'modelVersion': '1', 'modelSource': 'Train', 'state': 'Doing', 'modelVersionDesc': '', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-e6idgpqm5t3d', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.279196, 'total_latency': 0.2833338330092374, 'start_timestamp': 1723623212015}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:13:32Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:13:32Z/300/x-bce-date;content-type;request-source;host/fe68b2111fd186159f8c9f59d281f6d2d44fc5b9d16cf8764b9b41ca44ed7792', 'Content-Length': '26'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:13:32.302] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:14:02.309] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:14:02Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:14:02Z/300/x-bce-date;content-type;request-source;host/7645c58d4337756fd002ad48fff361c35384bb0726cb4509a103ee0a71276825'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:14:02.609] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:14:02 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3771', 'X-Bce-Request-Id': 'ee2b528f-78ed-4d22-848b-a32af33fe751', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '4280652297', 'result': {'evaluationId': 15546, 'evaluationIdStr': 'ame-v86j3sw988t0', 'name': 'sdk_eval_MCTK5U2uNE6', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 42564, 'modelVersionIdStr': 'amv-8t6qf24m4xcb', 'modelId': 34491, 'modelIdStr': 'am-mgf6icsebsa4', 'modelName': 'm_xNDPALyMT4db', 'modelVersion': '1', 'modelSource': 'Train', 'state': 'Doing', 'modelVersionDesc': '', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-e6idgpqm5t3d', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.290746, 'total_latency': 0.2946290410036454, 'start_timestamp': 1723623242311}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:14:02Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:14:02Z/300/x-bce-date;content-type;request-source;host/7645c58d4337756fd002ad48fff361c35384bb0726cb4509a103ee0a71276825', 'Content-Length': '26'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:14:02.610] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:14:32.618] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:14:32Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:14:32Z/300/x-bce-date;content-type;request-source;host/5f27244ff7afbd8f5a8e37f2a6ce02391b5558b209242ba9ed123491fef9c38a'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:14:32.982] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:14:33 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3771', 'X-Bce-Request-Id': '86b66ae6-3e79-44aa-a599-9e4c0c46d482', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '2444617355', 'result': {'evaluationId': 15546, 'evaluationIdStr': 'ame-v86j3sw988t0', 'name': 'sdk_eval_MCTK5U2uNE6', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 42564, 'modelVersionIdStr': 'amv-8t6qf24m4xcb', 'modelId': 34491, 'modelIdStr': 'am-mgf6icsebsa4', 'modelName': 'm_xNDPALyMT4db', 'modelVersion': '1', 'modelSource': 'Train', 'state': 'Doing', 'modelVersionDesc': '', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-e6idgpqm5t3d', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.353214, 'total_latency': 0.35807383300561924, 'start_timestamp': 1723623272619}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:14:32Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:14:32Z/300/x-bce-date;content-type;request-source;host/5f27244ff7afbd8f5a8e37f2a6ce02391b5558b209242ba9ed123491fef9c38a', 'Content-Length': '26'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:14:32.982] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:15:02.999] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:15:02Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:15:02Z/300/x-bce-date;content-type;request-source;host/5ce2e70427d215831921965a66813eae2bc2d493a984bf70c6acede329dc36d8'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:15:03.275] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:15:03 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3771', 'X-Bce-Request-Id': '09e86ded-e3af-45ac-b41d-2fb2d1850b9a', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '2646673003', 'result': {'evaluationId': 15546, 'evaluationIdStr': 'ame-v86j3sw988t0', 'name': 'sdk_eval_MCTK5U2uNE6', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 42564, 'modelVersionIdStr': 'amv-8t6qf24m4xcb', 'modelId': 34491, 'modelIdStr': 'am-mgf6icsebsa4', 'modelName': 'm_xNDPALyMT4db', 'modelVersion': '1', 'modelSource': 'Train', 'state': 'Doing', 'modelVersionDesc': '', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-e6idgpqm5t3d', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.26941, 'total_latency': 0.2720074590033619, 'start_timestamp': 1723623302999}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:15:02Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:15:02Z/300/x-bce-date;content-type;request-source;host/5ce2e70427d215831921965a66813eae2bc2d493a984bf70c6acede329dc36d8', 'Content-Length': '26'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:15:03.277] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:15:33.286] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:15:33Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:15:33Z/300/x-bce-date;content-type;request-source;host/788518415a8c4459eb6521e44316486e9e1253c3855a63e063268698eec2e27b'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# ...
# [INFO][2024-08-14 16:27:41.935] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:28:11.942] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:28:11Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:28:11Z/300/x-bce-date;content-type;request-source;host/5b5d252a71957b9cb0a3eb8fe0e7cb16ddf8c22782879ffba4a1e03a5a96e32f'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:28:12.223] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:28:12 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3815', 'X-Bce-Request-Id': 'd2ad6097-f9ed-4628-844e-8814e05cd3ac', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '3477971147', 'result': {'evaluationId': 15546, 'evaluationIdStr': 'ame-v86j3sw988t0', 'name': 'sdk_eval_MCTK5U2uNE6', 'description': '', 'state': 'Done', 'evalUnits': [{'modelVersionId': 42564, 'modelVersionIdStr': 'amv-8t6qf24m4xcb', 'modelId': 34491, 'modelIdStr': 'am-mgf6icsebsa4', 'modelName': 'm_xNDPALyMT4db', 'modelVersion': '1', 'modelSource': 'Train', 'state': 'Done', 'modelVersionDesc': '', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-e6idgpqm5t3d', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': 'ds-u7r7cmaa85y82vs9', 'inferDatasetState': 'success', 'inferDatasetName': 'sdk_eval_MCTK5U2uNE6_7mm66t', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.274112, 'total_latency': 0.27702545801003, 'start_timestamp': 1723624091943}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:28:11Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:28:11Z/300/x-bce-date;content-type;request-source;host/5b5d252a71957b9cb0a3eb8fe0e7cb16ddf8c22782879ffba4a1e03a5a96e32f', 'Content-Length': '26'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:28:12.224] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Done
# [TRACE][2024-08-14 16:28:12.225] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/report', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:28:12Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:28:12Z/300/x-bce-date;content-type;request-source;host/69cc472c5a0c0046b435a76669f7b38bfbec106bd194f66007fccc916a90ebf4'}, json_body={'id': 'ame-v86j3sw988t0'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [TRACE][2024-08-14 16:28:12.533] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/result/export', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:28:12Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:28:12Z/300/x-bce-date;content-type;request-source;host/055971612def3778d436fe1ef3e7626b0c85fe78300e2332ed54b19e7f2ad02a'}, json_body={'id': 'ame-v86j3sw988t0', 'exportType': 'local', 'exportOpt': 'total', 'exportContent': ['prompt', 'prediction', 'completion', 'metrics']}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [TRACE][2024-08-14 16:28:12.857] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/result/export/info', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:28:12Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:28:12Z/300/x-bce-date;content-type;request-source;host/2c1d12d8054e55f29198c93654ecdf2a5c178f436da899a3ab7e589cca6fd2b7'}, json_body={'exportID': 'amemt-qktvzg7p9vhy'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [INFO][2024-08-14 16:28:13.140] evaluation_manager.py:648 [t:8570851136]: wait evaluation result export task amemt-qktvzg7p9vhy to be completed
# [TRACE][2024-08-14 16:28:15.147] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/result/export/info', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:28:15Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:28:15Z/300/x-bce-date;content-type;request-source;host/c825cf78d21e278bb6f299c615c6d892091996300c57d6b113c6e80731469bb6'}, json_body={'exportID': 'amemt-qktvzg7p9vhy'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [INFO][2024-08-14 16:28:15.452] evaluation_manager.py:648 [t:8570851136]: wait evaluation result export task amemt-qktvzg7p9vhy to be completed
# [TRACE][2024-08-14 16:28:17.456] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/result/export/info', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:28:17Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:28:17Z/300/x-bce-date;content-type;request-source;host/3cde857a98cce779ae60dc00237c20e9fe28545565c95ab6035c8169e6b7918f'}, json_body={'exportID': 'amemt-qktvzg7p9vhy'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [INFO][2024-08-14 16:28:17.728] evaluation_manager.py:648 [t:8570851136]: wait evaluation result export task amemt-qktvzg7p9vhy to be completed
# [TRACE][2024-08-14 16:28:19.735] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/result/export/info', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:28:19Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:28:19Z/300/x-bce-date;content-type;request-source;host/08bf706aecb2849ac90dc2074c548da9fd26a2937f799d86c4b55e3eacb21c17'}, json_body={'exportID': 'amemt-qktvzg7p9vhy'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [INFO][2024-08-14 16:28:20.323] evaluation_manager.py:648 [t:8570851136]: wait evaluation result export task amemt-qktvzg7p9vhy to be completed
# [TRACE][2024-08-14 16:28:22.330] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/result/export/info', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:28:22Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:28:22Z/300/x-bce-date;content-type;request-source;host/6623ae153ad48e8f2d44f5ce2dd8987dcb39fcccc82471371a7de319ab3a07da'}, json_body={'exportID': 'amemt-qktvzg7p9vhy'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [INFO][2024-08-14 16:28:22.886] evaluation_manager.py:648 [t:8570851136]: wait evaluation result export task amemt-qktvzg7p9vhy to be completed
# [TRACE][2024-08-14 16:28:24.893] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/result/export/info', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:28:24Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:28:24Z/300/x-bce-date;content-type;request-source;host/148089c1aabbb523879c08c028e0d2654d56fd1ad95c758c3f0f956717ed7138'}, json_body={'exportID': 'amemt-qktvzg7p9vhy'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [INFO][2024-08-14 16:28:25.223] evaluation_manager.py:648 [t:8570851136]: wait evaluation result export task amemt-qktvzg7p9vhy to be completed
# [TRACE][2024-08-14 16:28:27.230] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/result/export/info', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:28:27Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:28:27Z/300/x-bce-date;content-type;request-source;host/688d350d45b07f6549157e5ae30852099515c281af9c5d5114b33908c1313312'}, json_body={'exportID': 'amemt-qktvzg7p9vhy'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [INFO][2024-08-14 16:28:27.603] evaluation_manager.py:661 [t:8570851136]: export result succeeded
# [INFO][2024-08-14 16:28:27.603] evaluation_manager.py:669 [t:8570851136]: start to download evaluation result file from https://aipe-dragonboat.bj.bcebos.com/qianfan_modelrepo/workspace/model_eval_result_export/sdk_eval_MCTK5U2uNE6_ame-v86j3sw988t0.zip?authorization=bce-auth-v1%2F50c8bb753dcb4e1d8646bb1ffefd3503%2F2024-08-14T08%3A28%3A25Z%2F-1%2Fhost%2Fa3efd052893d8d0f3418fa6c026385762c5521a516694abfedb321939dfaf111
# [INFO][2024-08-14 16:28:27.604] utils.py:763 [t:8570851136]: start to download file from url https://aipe-dragonboat.bj.bcebos.com/qianfan_modelrepo/workspace/model_eval_result_export/sdk_eval_MCTK5U2uNE6_ame-v86j3sw988t0.zip?authorization=bce-auth-v1%2F50c8bb753dcb4e1d8646bb1ffefd3503%2F2024-08-14T08%3A28%3A25Z%2F-1%2Fhost%2Fa3efd052893d8d0f3418fa6c026385762c5521a516694abfedb321939dfaf111
# [INFO][2024-08-14 16:28:27.969] file.py:291 [t:8570851136]: use format type FormatType.Jsonl
# [INFO][2024-08-14 16:28:27.973] utils.py:428 [t:8570851136]: need create cached arrow file for /Users/jianruitian/Documents/GitHub/bce-qianfan-sdk/cookbook/awesome_demo/dialogue multi-tag generation/tmp_folder/tmp_eval_modify.jsonl
# [INFO][2024-08-14 16:28:27.980] utils.py:484 [t:8570851136]: start to write arrow table to /Users/jianruitian/.qianfan_cache/dataset/Users/jianruitian/Documents/GitHub/bce-qianfan-sdk/cookbook/awesome_demo/dialogue multi-tag generation/tmp_folder/tmp_eval_modify.arrow
# [INFO][2024-08-14 16:28:28.332] utils.py:505 [t:8570851136]: writing succeeded
# [INFO][2024-08-14 16:28:28.333] utils.py:359 [t:8570851136]: start to get memory_map from /Users/jianruitian/.qianfan_cache/dataset/Users/jianruitian/Documents/GitHub/bce-qianfan-sdk/cookbook/awesome_demo/dialogue multi-tag generation/tmp_folder/tmp_eval_modify.arrow
# [INFO][2024-08-14 16:28:28.335] utils.py:284 [t:8570851136]: has got a memory-mapped table

# %%
print(result.metrics)
# Out:
# {'m_xNDPALyMT4db_1': {'accuracy': 0, 'f1Score': 0, 'rouge_1': 0, 'rouge_2': 0, 'rouge_l': 0, 'bleu4': 0, 'avgJudgeScore': 2.951613, 'stdJudgeScore': 0.3779153, 'medianJudgeScore': 3, 'scoreDistribution': {'-1': 0, '0': 1, '1': 0, '2': 0, '3': 61}, 'manualAvgScore': 0, 'goodCaseProportion': 0, 'subjectiveImpression': '', 'manualScoreDistribution': None}}

# %% [markdown]
# 为了体现微调的提升效果，在此对对未作精调前的模型进行评估：

# %%
raw_model = Model(id = "amv-sb5kfqie51z1")
# Out:
# [TRACE][2024-08-14 16:43:36.902] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/modelVersionDetail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:43:36Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:43:36Z/300/x-bce-date;content-type;request-source;host/56b13b32cc8b32c3ba31979a56b32b438fcee1c008f4968ffa58af3aaf9fd48e'}, json_body={'modelVersionId': 'amv-sb5kfqie51z1'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))

# %%
raw_result = em.eval([raw_model], eval_ds)
# Out:
# [TRACE][2024-08-14 16:43:38.164] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/modelVersionDetail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:43:38Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:43:38Z/300/x-bce-date;content-type;request-source;host/0d53af67e699e855dd8173ef0c3f884bb149619468508d0142403189b65850dc'}, json_body={'modelVersionId': 'amv-sb5kfqie51z1'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [TRACE][2024-08-14 16:43:38.750] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/create', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:43:38Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:43:38Z/300/x-bce-date;content-type;request-source;host/0b81a29bf046c149c98f23731bdb1a88ecc3e6eadf410b7edea58aa4f387cfaa'}, json_body={'name': 'sdk_eval_acYQRObZEgZ', 'versionEvalInfo': [{'modelId': 'am-xgk30z76e4gs', 'modelVersionId': 'amv-sb5kfqie51z1'}], 'datasetId': 'ds-n1dg1czx3ciqrakr', 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'maxScore': 3}}, 'computeResourceConf': {'vmType': 1, 'vmNumber': 8}}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [INFO][2024-08-14 16:43:40.333] evaluation_manager.py:377 [t:8570851136]: please check webpage https://console.bce.baidu.com/qianfan/modelcenter/model/eval/detail/task/ame-xndmt9y7rd5z to get further information
# [TRACE][2024-08-14 16:43:40.334] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:43:40Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:43:40Z/300/x-bce-date;content-type;request-source;host/5429f3215a0cd09ce288852761b6b08350e190261eddbe657b26048e5f3ee8fd'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:43:40.615] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:43:40 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3854', 'X-Bce-Request-Id': 'b1fb5d4f-5173-46aa-8ad7-5b5aa29e6024', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '4143342380', 'result': {'evaluationId': 15548, 'evaluationIdStr': 'ame-xndmt9y7rd5z', 'name': 'sdk_eval_acYQRObZEgZ', 'description': '', 'state': 'Pending', 'evalUnits': [{'modelVersionId': 19868, 'modelVersionIdStr': 'amv-sb5kfqie51z1', 'modelId': 16052, 'modelIdStr': 'am-xgk30z76e4gs', 'modelName': 'ERNIE Tiny', 'modelVersion': 'ERNIE-Tiny-8K', 'modelSource': 'PlatformPreset', 'state': 'Editing', 'modelVersionDesc': '2024年3月8日发布的初始版本，支持8K上下文长度', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-0xh916cvtt0p', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.27538, 'total_latency': 0.27830212500703055, 'start_timestamp': 1723625020335}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:43:40Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:43:40Z/300/x-bce-date;content-type;request-source;host/5429f3215a0cd09ce288852761b6b08350e190261eddbe657b26048e5f3ee8fd', 'Content-Length': '26'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:43:40.616] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Pending
# [TRACE][2024-08-14 16:44:10.623] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:44:10Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:44:10Z/300/x-bce-date;content-type;request-source;host/65524edd7b654c63af1a041f857b61a2093fc031114fba5320f4f08b06443356'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:44:10.883] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:44:10 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3850', 'X-Bce-Request-Id': '84491156-890a-4d90-bda3-1ad075d580d1', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '2215868835', 'result': {'evaluationId': 15548, 'evaluationIdStr': 'ame-xndmt9y7rd5z', 'name': 'sdk_eval_acYQRObZEgZ', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 19868, 'modelVersionIdStr': 'amv-sb5kfqie51z1', 'modelId': 16052, 'modelIdStr': 'am-xgk30z76e4gs', 'modelName': 'ERNIE Tiny', 'modelVersion': 'ERNIE-Tiny-8K', 'modelSource': 'PlatformPreset', 'state': 'Doing', 'modelVersionDesc': '2024年3月8日发布的初始版本，支持8K上下文长度', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-0xh916cvtt0p', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.249891, 'total_latency': 0.25406204200407956, 'start_timestamp': 1723625050625}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:44:10Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:44:10Z/300/x-bce-date;content-type;request-source;host/65524edd7b654c63af1a041f857b61a2093fc031114fba5320f4f08b06443356', 'Content-Length': '26'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:44:10.884] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:44:40.817] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:44:40Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:44:40Z/300/x-bce-date;content-type;request-source;host/08405824a1741443f05b2408c7ff6f3400c2353eb700f92436126c9a3df3ea51'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:44:41.121] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:44:41 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3850', 'X-Bce-Request-Id': '72119f0e-61e0-4ec5-92e0-27c686cfd50c', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '2456370395', 'result': {'evaluationId': 15548, 'evaluationIdStr': 'ame-xndmt9y7rd5z', 'name': 'sdk_eval_acYQRObZEgZ', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 19868, 'modelVersionIdStr': 'amv-sb5kfqie51z1', 'modelId': 16052, 'modelIdStr': 'am-xgk30z76e4gs', 'modelName': 'ERNIE Tiny', 'modelVersion': 'ERNIE-Tiny-8K', 'modelSource': 'PlatformPreset', 'state': 'Doing', 'modelVersionDesc': '2024年3月8日发布的初始版本，支持8K上下文长度', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-0xh916cvtt0p', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.299366, 'total_latency': 0.30164954099745955, 'start_timestamp': 1723625080817}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:44:40Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:44:40Z/300/x-bce-date;content-type;request-source;host/08405824a1741443f05b2408c7ff6f3400c2353eb700f92436126c9a3df3ea51', 'Content-Length': '26'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:44:41.122] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:45:11.107] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:45:11Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:45:11Z/300/x-bce-date;content-type;request-source;host/f0d61533eba7aa3b160c199a4d9258bd080b6e6b7aa70f9161e28ccc5f074555'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:45:11.447] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:45:11 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3850', 'X-Bce-Request-Id': '0c122a67-0168-4a21-9073-30865205fc13', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '2734116854', 'result': {'evaluationId': 15548, 'evaluationIdStr': 'ame-xndmt9y7rd5z', 'name': 'sdk_eval_acYQRObZEgZ', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 19868, 'modelVersionIdStr': 'amv-sb5kfqie51z1', 'modelId': 16052, 'modelIdStr': 'am-xgk30z76e4gs', 'modelName': 'ERNIE Tiny', 'modelVersion': 'ERNIE-Tiny-8K', 'modelSource': 'PlatformPreset', 'state': 'Doing', 'modelVersionDesc': '2024年3月8日发布的初始版本，支持8K上下文长度', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-0xh916cvtt0p', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.332246, 'total_latency': 0.3357373750041006, 'start_timestamp': 1723625111107}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:45:11Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:45:11Z/300/x-bce-date;content-type;request-source;host/f0d61533eba7aa3b160c199a4d9258bd080b6e6b7aa70f9161e28ccc5f074555', 'Content-Length': '26'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:45:11.448] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:45:41.449] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:45:41Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:45:41Z/300/x-bce-date;content-type;request-source;host/165ecfc43ac3d967d85574e6e35fa222ffb1ca9a5d20c01e99ddd85f0d457790'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:45:41.787] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:45:41 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3850', 'X-Bce-Request-Id': '98fbdb8f-a574-4fdf-8fc3-0420e10f7da1', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '3001226830', 'result': {'evaluationId': 15548, 'evaluationIdStr': 'ame-xndmt9y7rd5z', 'name': 'sdk_eval_acYQRObZEgZ', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 19868, 'modelVersionIdStr': 'amv-sb5kfqie51z1', 'modelId': 16052, 'modelIdStr': 'am-xgk30z76e4gs', 'modelName': 'ERNIE Tiny', 'modelVersion': 'ERNIE-Tiny-8K', 'modelSource': 'PlatformPreset', 'state': 'Doing', 'modelVersionDesc': '2024年3月8日发布的初始版本，支持8K上下文长度', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-0xh916cvtt0p', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.329974, 'total_latency': 0.33359870899585076, 'start_timestamp': 1723625141450}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:45:41Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:45:41Z/300/x-bce-date;content-type;request-source;host/165ecfc43ac3d967d85574e6e35fa222ffb1ca9a5d20c01e99ddd85f0d457790', 'Content-Length': '26'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:45:41.788] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:46:11.795] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:46:11Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:46:11Z/300/x-bce-date;content-type;request-source;host/ee28c376fba28bfdd3fbb11b0d0045c573b192c398e97291bab0d8a1ca3cdfba'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:46:12.078] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:46:12 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3850', 'X-Bce-Request-Id': 'd7f05459-ab62-496a-8315-757be2d106e8', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '3252620250', 'result': {'evaluationId': 15548, 'evaluationIdStr': 'ame-xndmt9y7rd5z', 'name': 'sdk_eval_acYQRObZEgZ', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 19868, 'modelVersionIdStr': 'amv-sb5kfqie51z1', 'modelId': 16052, 'modelIdStr': 'am-xgk30z76e4gs', 'modelName': 'ERNIE Tiny', 'modelVersion': 'ERNIE-Tiny-8K', 'modelSource': 'PlatformPreset', 'state': 'Doing', 'modelVersionDesc': '2024年3月8日发布的初始版本，支持8K上下文长度', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-0xh916cvtt0p', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.272758, 'total_latency': 0.2769709170097485, 'start_timestamp': 1723625171796}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:46:11Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:46:11Z/300/x-bce-date;content-type;request-source;host/ee28c376fba28bfdd3fbb11b0d0045c573b192c398e97291bab0d8a1ca3cdfba', 'Content-Length': '26'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:46:12.080] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:46:42.086] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:46:42Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:46:42Z/300/x-bce-date;content-type;request-source;host/8e890f083c93669c675e778cfd678eef51d416bd2f2c2703785fc665fb3b22f7'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:46:42.394] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:46:42 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3850', 'X-Bce-Request-Id': '00a22423-a4aa-4b12-9b1a-7d35f19cdbfb', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '3472430375', 'result': {'evaluationId': 15548, 'evaluationIdStr': 'ame-xndmt9y7rd5z', 'name': 'sdk_eval_acYQRObZEgZ', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 19868, 'modelVersionIdStr': 'amv-sb5kfqie51z1', 'modelId': 16052, 'modelIdStr': 'am-xgk30z76e4gs', 'modelName': 'ERNIE Tiny', 'modelVersion': 'ERNIE-Tiny-8K', 'modelSource': 'PlatformPreset', 'state': 'Doing', 'modelVersionDesc': '2024年3月8日发布的初始版本，支持8K上下文长度', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-0xh916cvtt0p', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.301148, 'total_latency': 0.3039901669981191, 'start_timestamp': 1723625202088}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:46:42Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:46:42Z/300/x-bce-date;content-type;request-source;host/8e890f083c93669c675e778cfd678eef51d416bd2f2c2703785fc665fb3b22f7', 'Content-Length': '26'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:46:42.395] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:47:12.401] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:47:12Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:47:12Z/300/x-bce-date;content-type;request-source;host/8d2a997916643d1b821fd34156873bce2904c4ce2870e71e5eee724e7d82efad'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:47:12.685] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:47:12 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3850', 'X-Bce-Request-Id': 'dfd1088d-626a-4416-8482-0d8e9951811d', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '3716260926', 'result': {'evaluationId': 15548, 'evaluationIdStr': 'ame-xndmt9y7rd5z', 'name': 'sdk_eval_acYQRObZEgZ', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 19868, 'modelVersionIdStr': 'amv-sb5kfqie51z1', 'modelId': 16052, 'modelIdStr': 'am-xgk30z76e4gs', 'modelName': 'ERNIE Tiny', 'modelVersion': 'ERNIE-Tiny-8K', 'modelSource': 'PlatformPreset', 'state': 'Doing', 'modelVersionDesc': '2024年3月8日发布的初始版本，支持8K上下文长度', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-0xh916cvtt0p', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.276425, 'total_latency': 0.2802827500127023, 'start_timestamp': 1723625232402}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:47:12Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:47:12Z/300/x-bce-date;content-type;request-source;host/8d2a997916643d1b821fd34156873bce2904c4ce2870e71e5eee724e7d82efad', 'Content-Length': '26'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:47:12.686] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:47:42.692] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:47:42Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:47:42Z/300/x-bce-date;content-type;request-source;host/b8ad5d96a552e41e3c220e7ba540f4d93e62af3db164eda8c68b58c020d05145'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:47:42.991] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:47:43 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3850', 'X-Bce-Request-Id': 'ff6dc5fd-88bf-409a-908b-15cc32a85b01', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '3952429767', 'result': {'evaluationId': 15548, 'evaluationIdStr': 'ame-xndmt9y7rd5z', 'name': 'sdk_eval_acYQRObZEgZ', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 19868, 'modelVersionIdStr': 'amv-sb5kfqie51z1', 'modelId': 16052, 'modelIdStr': 'am-xgk30z76e4gs', 'modelName': 'ERNIE Tiny', 'modelVersion': 'ERNIE-Tiny-8K', 'modelSource': 'PlatformPreset', 'state': 'Doing', 'modelVersionDesc': '2024年3月8日发布的初始版本，支持8K上下文长度', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-0xh916cvtt0p', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': '', 'inferDatasetState': 'pending', 'inferDatasetName': '', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.289821, 'total_latency': 0.29387425001186784, 'start_timestamp': 1723625262694}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:47:42Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:47:42Z/300/x-bce-date;content-type;request-source;host/b8ad5d96a552e41e3c220e7ba540f4d93e62af3db164eda8c68b58c020d05145', 'Content-Length': '26'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:47:42.992] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:48:12.996] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:48:12Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:48:12Z/300/x-bce-date;content-type;request-source;host/d7a3951359154fbb80e0139a1a44fec5e0bad37da2c587f95d47688efafc04ba'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# ...
# [INFO][2024-08-14 16:51:45.428] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:52:15.439] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:52:15Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:52:15Z/300/x-bce-date;content-type;request-source;host/39495bf3a2a1bc6df9813e535d8ff1492be3593b7ead274111d23733aacb52cd'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:52:15.740] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:52:15 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3896', 'X-Bce-Request-Id': '359225cc-ae7e-4186-a03b-b37e9c3e13e0', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '3969899957', 'result': {'evaluationId': 15548, 'evaluationIdStr': 'ame-xndmt9y7rd5z', 'name': 'sdk_eval_acYQRObZEgZ', 'description': '', 'state': 'Doing', 'evalUnits': [{'modelVersionId': 19868, 'modelVersionIdStr': 'amv-sb5kfqie51z1', 'modelId': 16052, 'modelIdStr': 'am-xgk30z76e4gs', 'modelName': 'ERNIE Tiny', 'modelVersion': 'ERNIE-Tiny-8K', 'modelSource': 'PlatformPreset', 'state': 'Doing', 'modelVersionDesc': '2024年3月8日发布的初始版本，支持8K上下文长度', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-0xh916cvtt0p', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': 'ds-ghqnzt3t4eefki86', 'inferDatasetState': 'success', 'inferDatasetName': 'sdk_eval_acYQRObZEgZ_y0jkhj', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.295192, 'total_latency': 0.29809279199980665, 'start_timestamp': 1723625535440}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:52:15Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:52:15Z/300/x-bce-date;content-type;request-source;host/39495bf3a2a1bc6df9813e535d8ff1492be3593b7ead274111d23733aacb52cd', 'Content-Length': '26'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:52:15.741] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Doing
# [TRACE][2024-08-14 16:52:45.747] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:52:45Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:52:45Z/300/x-bce-date;content-type;request-source;host/a2a78928106095a682b80b6c9cf518692acd46b3ceb1015ea2d6a07cd1bba816'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [DEBUG][2024-08-14 16:52:45.996] evaluation_manager.py:384 [t:8570851136]: current evaluation task info: QfResponse(code=200, headers={'Date': 'Wed, 14 Aug 2024 08:52:46 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3894', 'X-Bce-Request-Id': '230fc5a8-4c4d-4704-8992-c3ba84ad042a', 'X-Bce-Gateway-Region': 'SZ'}, body={'log_id': '4190371701', 'result': {'evaluationId': 15548, 'evaluationIdStr': 'ame-xndmt9y7rd5z', 'name': 'sdk_eval_acYQRObZEgZ', 'description': '', 'state': 'Done', 'evalUnits': [{'modelVersionId': 19868, 'modelVersionIdStr': 'amv-sb5kfqie51z1', 'modelId': 16052, 'modelIdStr': 'am-xgk30z76e4gs', 'modelName': 'ERNIE Tiny', 'modelVersion': 'ERNIE-Tiny-8K', 'modelSource': 'PlatformPreset', 'state': 'Done', 'modelVersionDesc': '2024年3月8日发布的初始版本，支持8K上下文长度', 'message': '', 'modelTags': None, 'evalUnitId': 'ameu-0xh916cvtt0p', 'modelForm': 'model', 'createNewInferDataset': True, 'inferDatasetId': 'ds-ghqnzt3t4eefki86', 'inferDatasetState': 'success', 'inferDatasetName': 'sdk_eval_acYQRObZEgZ_y0jkhj', 'inferDatasetStorageType': 'sysBos', 'inferDatasetStorageId': '', 'inferDatasetRawPath': '', 'inferDatasetErrMsg': '', 'prompt': {'enable': False}}], 'datasetId': 102920, 'datasetName': '预置数据集>客服对话多标签生成评估数据集>V1', 'computeResourceConf': {'vmType': 1, 'vmNumber': 8, 'computeResourceId': '', 'cpu': 0, 'memory': 0}, 'evalStandardConf': {'evalMode': 'model', 'appId': 105835560, 'appAk': 'Ubujx6au2SOnkaZQYm8d8Lj5', 'appSk': 'YZNtoIvR0yunVSsTaKebs5089fju6VCW', 'apiName': 'ERNIE-Bot', 'apiUrl': 'https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions', 'prompt': {'templateName': '裁判员模型打分模板 (含参考答案)', 'templateContent': '【系统】\n请作为一个公正的裁判，评估下面给定用户问题的AI助手所提供回答的质量。您的评估应该考虑以下因素：\n{参照总体组设计，分为理解、生成、事实、逻辑、指令遵循五个维度综合考察AI助手能力。详细评分方法如下：\n    * 理解：仅考虑回答的扣题程度，不考虑回答的正确性。\n        * 核心需求是否理解；\n        * 非核心需求是否理解；\n    * 生成：考虑（1）回答和问题的相关性、（2）生成文本的质量。\n        * 核心需求是否体现在答案里；\n        * 核心需求体现在答案，但是否正确实现。\n    * 逻辑：考虑回答的逻辑正确性与一致性\n        * 创作/问答的逻辑主要指的是行文逻辑、发展逻辑、论证逻辑等；\n        * 信息处理/代码/数学计算/逻辑推理的逻辑包括推理/计算步骤与答案正确性;\n    * 事实：前提是符合中国的国情和政治立场、法律法规和文化价值观要准确，主要指回答问题涉及的外部客观事实正确性，回复提供的信息要准确、真实、可靠、有帮助。\n    * 指令遵循：回答是否严格遵循用户问题的要求，比如是否提供了所有要求的信息，要按照给定样例格式输出回答，遇到选择或分类题应当直接输出答案而不用补充说明。}\n请帮助我评估AI助手回答的好坏并给出对应的{{min_score}}到{{max_score}}得分，{最终只需要给出一个综合的得分。}\n【用户的问题】\n ```json\n{\n    "instruction": "{{src}}",\n}\n```\n【参考的回答】\n```json\n[\n    {\n        "target": "{{tgt}}"\n    }\n]\n```\n【助手的回答】\n```json\n[\n    {\n        "answer": "{{prediction}}"\n    }\n]\n```\n【输出格式】\n```json\n{\n    "reason": "",\n    "score": ""\n}\n```\n请注意区分您的最终任务和用户问题中提出的任务，最终的任务是完成评估打分任务，而不要直接回答给定的用户问题。\n请按照输出格式给出评分理由和助手回答的得分，不要输出json格式外的内容。\n【评估结果】', 'metric': '综合得分', 'steps': '\n请你对模型的输出进行评分，阅读输出的格式与内容。评分按照1-2-3三档执行，其中1分表示输出格式不对；2分表示输出格式正确，但内容不正确；3分表示输出的格式和内容全部正确。', 'minScore': 0, 'maxScore': 3}}, 'datasetIdStr': 'ds-n1dg1czx3ciqrakr'}}, statistic={'request_latency': 0.245834, 'total_latency': 0.24759295799594838, 'start_timestamp': 1723625565747}, request=QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/detail', query={}, headers={'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:52:45Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:52:45Z/300/x-bce-date;content-type;request-source;host/a2a78928106095a682b80b6c9cf518692acd46b3ceb1015ea2d6a07cd1bba816', 'Content-Length': '26'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=10, max_wait_interval=120, backoff_factor=1, jitter=1, retry_err_codes={})))
# [INFO][2024-08-14 16:52:45.997] evaluation_manager.py:385 [t:8570851136]: current eval_state: EvaluationTaskStatus.Done
# [TRACE][2024-08-14 16:52:45.997] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/report', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:52:45Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:52:45Z/300/x-bce-date;content-type;request-source;host/9315615aef2c2306aaa186bbb658eb9862be0ceeefe69a1c9f9d6ba2bbd4217a'}, json_body={'id': 'ame-xndmt9y7rd5z'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [TRACE][2024-08-14 16:52:46.297] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/result/export', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:52:46Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:52:46Z/300/x-bce-date;content-type;request-source;host/2a9569209f8028e0a9c15f8346e80483ff4eab5c4c8ea5b8a737490fd8d554ec'}, json_body={'id': 'ame-xndmt9y7rd5z', 'exportType': 'local', 'exportOpt': 'total', 'exportContent': ['prompt', 'prediction', 'completion', 'metrics']}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [TRACE][2024-08-14 16:52:46.590] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/result/export/info', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:52:46Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:52:46Z/300/x-bce-date;content-type;request-source;host/416decad937f5ae38be9680d101d276f816fe8ea1d0e2b346b689dcccc6f067b'}, json_body={'exportID': 'amemt-xbf6h2942amm'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [INFO][2024-08-14 16:52:46.808] evaluation_manager.py:648 [t:8570851136]: wait evaluation result export task amemt-xbf6h2942amm to be completed
# [TRACE][2024-08-14 16:52:48.816] base.py:175 [t:8570851136]: raw request: QfRequest(method='POST', url='https://qianfan.baidubce.com/wenxinworkshop/modelrepo/eval/result/export/info', query={}, headers={'Content-Type': 'application/json', 'Host': 'qianfan.baidubce.com', 'request-source': 'qianfan_py_sdk_v0.4.5', 'x-bce-date': '2024-08-14T08:52:48Z', 'Authorization': 'bce-auth-v1/2d9f701d872f4f54b69274e9a17ff5b2/2024-08-14T08:52:48Z/300/x-bce-date;content-type;request-source;host/e2d9689bf515e4568304f9912fc2df0c0504cf12ad7fd3f120733ac78a0c39fe'}, json_body={'exportID': 'amemt-xbf6h2942amm'}, files={}, retry_config=RetryConfig(retry_count=1, timeout=60, max_wait_interval=120.0, backoff_factor=0, jitter=1.0, retry_err_codes={500000, 18, 336100}))
# [INFO][2024-08-14 16:52:49.151] evaluation_manager.py:661 [t:8570851136]: export result succeeded
# [INFO][2024-08-14 16:52:49.152] evaluation_manager.py:669 [t:8570851136]: start to download evaluation result file from https://aipe-dragonboat.bj.bcebos.com/qianfan_modelrepo/workspace/model_eval_result_export/sdk_eval_acYQRObZEgZ_ame-xndmt9y7rd5z.zip?authorization=bce-auth-v1%2F50c8bb753dcb4e1d8646bb1ffefd3503%2F2024-08-14T08%3A52%3A47Z%2F-1%2Fhost%2F380f79e139c4ecc79781ad9992bdd845a409da20ed0b85f8c1fb2a2f88d36498
# [INFO][2024-08-14 16:52:49.155] utils.py:763 [t:8570851136]: start to download file from url https://aipe-dragonboat.bj.bcebos.com/qianfan_modelrepo/workspace/model_eval_result_export/sdk_eval_acYQRObZEgZ_ame-xndmt9y7rd5z.zip?authorization=bce-auth-v1%2F50c8bb753dcb4e1d8646bb1ffefd3503%2F2024-08-14T08%3A52%3A47Z%2F-1%2Fhost%2F380f79e139c4ecc79781ad9992bdd845a409da20ed0b85f8c1fb2a2f88d36498
# [INFO][2024-08-14 16:52:49.567] file.py:291 [t:8570851136]: use format type FormatType.Jsonl
# [INFO][2024-08-14 16:52:49.572] utils.py:428 [t:8570851136]: need create cached arrow file for /Users/jianruitian/Documents/GitHub/bce-qianfan-sdk/cookbook/awesome_demo/dialogue multi-tag generation/tmp_folder/tmp_eval_modify.jsonl
# [INFO][2024-08-14 16:52:49.572] utils.py:484 [t:8570851136]: start to write arrow table to /Users/jianruitian/.qianfan_cache/dataset/Users/jianruitian/Documents/GitHub/bce-qianfan-sdk/cookbook/awesome_demo/dialogue multi-tag generation/tmp_folder/tmp_eval_modify.arrow
# [INFO][2024-08-14 16:52:49.581] utils.py:505 [t:8570851136]: writing succeeded
# [INFO][2024-08-14 16:52:49.583] utils.py:359 [t:8570851136]: start to get memory_map from /Users/jianruitian/.qianfan_cache/dataset/Users/jianruitian/Documents/GitHub/bce-qianfan-sdk/cookbook/awesome_demo/dialogue multi-tag generation/tmp_folder/tmp_eval_modify.arrow
# [INFO][2024-08-14 16:52:49.584] utils.py:284 [t:8570851136]: has got a memory-mapped table

# %%
print(raw_result.metrics)
# Out:
# {'ERNIE Tiny_ERNIE-Tiny-8K': {'accuracy': 0, 'f1Score': 0, 'rouge_1': 0, 'rouge_2': 0, 'rouge_l': 0, 'bleu4': 0, 'avgJudgeScore': 1.3548387, 'stdJudgeScore': 0.9688166, 'medianJudgeScore': 1, 'scoreDistribution': {'-1': 0, '0': 14, '1': 20, '2': 20, '3': 8}, 'manualAvgScore': 0, 'goodCaseProportion': 0, 'subjectiveImpression': '', 'manualScoreDistribution': None}}

# %% [markdown]
# 根据结果可以看到：基于ERNIE-Tiny-8K模型使用SFT全量更新的训练方法，且训练参数Epoch=1、Learning Rate=1e-5、序列长度=4096时，模型输出效果远远优于微调之前。

# %% [markdown]
# | 模型                        | 训练方法 | Epoch | Learning Rate | 序列长度 | 评估结果-0分 | 评估结果-1分 | 评估结果-2分 | 评估结果-3分 | 评估结果  |
# |-----------------------------|----------|-------|---------------|----------|--------|------|--------------|--------------|------------|
# | ERNIE-Tiny-8K (微调前)      | --       | --    | --            | --   |   14    | 20           | 20           | 8           | 0.9688166   |
# | ERNIE-Tiny-8K (微调后)      | 全量更新 | 1     | 1e-5          | 4096     |   0   | 1            | 0            | 61           | 2.951613   |
